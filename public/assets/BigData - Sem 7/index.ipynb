# %%
import pandas as pd
import ace_tools_open as tools
print("ACE Tools Open imported successfully.")
# Out:
# ACE Tools Open imported successfully.

# %%
# Create Quantitative Data Example
quant_df = pd.DataFrame({
    'timestamp': [
        '2025-04-01 08:00:00',
        '2025-04-01 09:00:00',
        '2025-04-01 10:00:00',
        '2025-04-01 11:00:00',
        '2025-04-01 12:00:00',
    ],
    'temperature_C': [22.5, 23.0, 24.1, 24.8, 25.0],
    'humidity_%': [45, 47, 50, 52, 55]
})
quant_df.to_csv('contoh_data_quantitative.csv', index=False)

# Create Qualitative Data Example
qual_df = pd.DataFrame({
    'feedback_id': [1, 2, 3, 4, 5],
    'review_text': [
        'Sangat puas dengan layanan',
        'Menu terlalu terbatas',
        'Pelayanan cepat dan ramah',
        'Harga kurang bersaing',
        'Tempat kurang bersih'
    ],
    'category': ['Positif', 'Negatif', 'Positif', 'Negatif', 'Negatif']
})
qual_df.to_csv('contoh_data_qualitative.csv', index=False)

# Create Statistical Data Example
stat_df = pd.DataFrame({
    'date': [
        '2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04', '2025-01-05'
    ],
    'daily_sales': [150, 200, 180, 220, 210]
})
stat_df.to_csv('contoh_data_statistical.csv', index=False)
print("Dataframes have been created and saved as CSV files.")
# Out:
# Dataframes have been created and saved as CSV files.

# %%
# Display dataframes to the user
tools.display_dataframe_to_user("Contoh Data Quantitative", quant_df)
tools.display_dataframe_to_user("Contoh Data Qualitative", qual_df)
tools.display_dataframe_to_user("Contoh Data Statistical", stat_df)
# Out:
# Contoh Data Quantitative
# <table id="itables_ab5ec92d_92e4_4c44_9343_74bbdf942124" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>timestamp</th>
#       <th>temperature_C</th>
#       <th>humidity_%</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
# ...
